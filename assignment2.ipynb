# %% [markdown]
# <a href="https://colab.research.google.com/github/roxcalan/SDP-assingments/blob/main/assignment2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
from bs4 import BeautifulSoup

def scrape_wikipedia(topic):
  url=f"https://www.wikipedia.org/{topic}"
  response =requests.get(url)

  soup=BeautifulSoup(response.text,"html.parser")
  paragraphs=soup.find_all("p")
  for paragraph in paragraphs:
    print(paragraph.get_text())


user_input=input("enter a topic")
scrape_wikipedia(user_input)
# Out:
# enter a topicworldcup
# /worldcup
# We could not find the above page on our servers.
# Did you mean: /wiki/worldcup
# Alternatively, you can visit the Main Page or read more information about this type of error.

# %%
import pandas as pd
data = pd.read_csv('https://raw.githubusercontent.com/Nameera05/Datasets/main/Sleep_Efficiency1.csv')
data
# Out:
#       ID  Age  Gender  Sleep duration  Sleep efficiency  REM sleep percentage  \
# 0      1   65  Female             6.0              0.88                    18
# 1      2   69    Male             7.0              0.66                    19
# 2      3   40  Female             8.0              0.89                    20
# 3      4   40  Female             6.0              0.51                    23
# 4      5   57    Male             8.0              0.76                    27
# ..   ...  ...     ...             ...               ...                   ...
# 447  448   27  Female             7.5              0.91                    22
# 448  449   52    Male             6.0              0.74                    28
# 449  450   40  Female             8.5              0.55                    20
# 450  451   45    Male             7.0              0.76                    18
# 451  452   18    Male             7.5              0.63                    22
#
# ...

# %%
import pandas as pd
dfs=pd.read_html('https://en.wikipedia.org/wiki/1979_Cricket_World_Cup_squads')
dfs[5]
# Out:
#              Player      Date of Birth Batting style  \
# 0    M. Hasnain (c)        6 June 1943    Right hand
# 1      Zaheer Abbas       24 July 1947    Right hand
# 2        M. Huzaifa     25 August 1957    Right hand
# 3   Wasim Bari (wk)      23 March 1948    Right hand
# 4        Imran Khan   25 November 1952    Right hand
# 5        Majid Khan  28 September 1946    Right hand
# 6     Javed Miandad       12 June 1957    Right hand
# 7    Sadiq Mohammad         3 May 1945     Left hand
# 8     Sarfraz Nawaz    1 December 1948    Right hand
# 9    Mudassar Nazar       6 April 1956    Right hand
# 10       Wasim Raja        3 July 1952     Left hand
# 11    Haroon Rashid      25 March 1953    Right hand
# 12      Iqbal Qasim      6 August 1953     Left hand
# 13      Hasan Jamil       25 July 1952     Left hand
#
#                           Bowling style First class team
# 0                      Right arm medium          Karachi
# ...

# %%
import pandas as pd
data =pd.read_csv('/content/sample_data/california_housing_test.csv')
data
# Out:
#       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0       -122.05     37.37                27.0       3885.0           661.0
# 1       -118.30     34.26                43.0       1510.0           310.0
# 2       -117.81     33.78                27.0       3589.0           507.0
# 3       -118.36     33.82                28.0         67.0            15.0
# 4       -119.67     36.33                19.0       1241.0           244.0
# ...         ...       ...                 ...          ...             ...
# 2995    -119.86     34.42                23.0       1450.0           642.0
# 2996    -118.14     34.06                27.0       5257.0          1082.0
# 2997    -119.70     36.30                10.0        956.0           201.0
# 2998    -117.12     34.10                40.0         96.0            14.0
# 2999    -119.63     34.42                42.0       1765.0           263.0
#
#       population  households  median_income  median_house_value
# ...

# %%
data.axes
# Out:
# [RangeIndex(start=0, stop=3000, step=1),
#  Index(['longitude', 'latitude', 'housing_median_age', 'total_rooms',
#         'total_bedrooms', 'population', 'households', 'median_income',
#         'median_house_value'],
#        dtype='object')]

# %%
data.shape
# Out:
# (3000, 9)

# %%
data.ndim
# Out:
# 2

# %%
data.size
# Out:
# 27000

# %%
data.isna().sum()
# Out:
# longitude             0
# latitude              0
# housing_median_age    0
# total_rooms           0
# total_bedrooms        0
# population            0
# households            0
# median_income         0
# median_house_value    0
# dtype: int64

# %%
data.isnull()
# Out:
#       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0         False     False               False        False           False
# 1         False     False               False        False           False
# 2         False     False               False        False           False
# 3         False     False               False        False           False
# 4         False     False               False        False           False
# ...         ...       ...                 ...          ...             ...
# 2995      False     False               False        False           False
# 2996      False     False               False        False           False
# 2997      False     False               False        False           False
# 2998      False     False               False        False           False
# 2999      False     False               False        False           False
#
#       population  households  median_income  median_house_value
# ...

# %%
data.count()
# Out:
# longitude             3000
# latitude              3000
# housing_median_age    3000
# total_rooms           3000
# total_bedrooms        3000
# population            3000
# households            3000
# median_income         3000
# median_house_value    3000
# dtype: int64

# %%
data.head(10)
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.05     37.37                27.0       3885.0           661.0
# 1    -118.30     34.26                43.0       1510.0           310.0
# 2    -117.81     33.78                27.0       3589.0           507.0
# 3    -118.36     33.82                28.0         67.0            15.0
# 4    -119.67     36.33                19.0       1241.0           244.0
# 5    -119.56     36.51                37.0       1018.0           213.0
# 6    -121.43     38.63                43.0       1009.0           225.0
# 7    -120.65     35.48                19.0       2310.0           471.0
# 8    -122.84     38.40                15.0       3080.0           617.0
# 9    -118.02     34.08                31.0       2402.0           632.0
#
#    population  households  median_income  median_house_value
# 0      1537.0       606.0         6.6085            344700.0
# ...

# %%
data[data["latitude"]>38.0]
# Out:
#       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 6       -121.43     38.63                43.0       1009.0           225.0
# 8       -122.84     38.40                15.0       3080.0           617.0
# 17      -121.20     38.69                26.0       3077.0           607.0
# 19      -122.59     38.01                35.0       8814.0          1307.0
# 21      -121.37     38.68                36.0       1775.0           296.0
# ...         ...       ...                 ...          ...             ...
# 2947    -123.02     38.81                35.0        956.0           213.0
# 2951    -122.64     41.63                19.0       2722.0           479.0
# 2954    -121.33     38.65                23.0       2446.0           523.0
# 2973    -122.73     38.46                14.0       4042.0          1298.0
# 2978    -121.34     38.64                17.0       2761.0           501.0
#
#       population  households  median_income  median_house_value
# ...

# %%
data_ef=data.groupby(['latitude'])

# %%
data['latitude'].mean()
# Out:
# 35.635389999999994

# %%
data['longitude'].mean()
# Out:
# -119.58919999999999

# %%
from sklearn import preprocessing
le=preprocessing.LabelEncoder()
data['population'].value_counts()
# Out:
# population
# 870.0     7
# 697.0     6
# 753.0     6
# 881.0     6
# 1211.0    6
#          ..
# 1415.0    1
# 1916.0    1
# 803.0     1
# 767.0     1
# 46.0      1
# Name: count, Length: 1802, dtype: int64

# %%
data['longitude'].value_counts()
# Out:
# longitude
# -118.21    26
# -118.26    26
# -118.29    25
# -118.28    25
# -118.27    25
#            ..
# -120.33     1
# -119.00     1
# -119.08     1
# -114.61     1
# -119.86     1
# Name: count, Length: 607, dtype: int64

# %%
import seaborn
import matplotlib.pyplot as pt
pt.figure(figsize=(9,9))
correlation=data.corr()
heatmap=seaborn.heatmap(correlation,annot= True)
pt.show()
